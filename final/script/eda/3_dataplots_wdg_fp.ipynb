# %% [markdown]
# #### PLOTTING
#
# "Looking" for Correlations or Trends

# %%
# import libraries
import pandas as  pd
import matplotlib.pyplot as plt
import os

from matplotlib import style
# 
style.use('ggplot')

# %%
# load dataset
#read in updated dataset
file_path ="../../resources/data/recession_fp.csv"
# file_path ="../../resources/data/great_recession_index.csv
# file_dir=os.path.join("resources")
recession_df = pd.read_csv(file_path)
recession_df
# Out:
#       record_no iso_code      geo_reg  year  population           gdp     co2  \
# 0             7      AFG  Afghanistan  2007    27101000  3.962899e+10   2.269
# 1             8      AFG  Afghanistan  2008    27722000  4.056158e+10   4.200
# 2             9      AFG  Afghanistan  2009    28395000  4.753980e+10   6.740
# 3            10      AFG  Afghanistan  2010    29186000  4.906888e+10   8.398
# 4            11      AFG  Afghanistan  2011    30117000  5.332634e+10  12.106
# ...         ...      ...          ...   ...         ...           ...     ...
# 1368       4511      ZWE     Zimbabwe  2008    12380000  1.430100e+10   7.719
# 1369       4512      ZWE     Zimbabwe  2009    12527000  1.514130e+10   5.476
# 1370       4513      ZWE     Zimbabwe  2010    12698000  1.660410e+10   7.864
# 1371       4514      ZWE     Zimbabwe  2011    12894000  1.830726e+10   9.480
# 1372       4515      ZWE     Zimbabwe  2012    13115000  2.048226e+10   7.659
#
# ...

# %%
#create a new dataframe inclusive of Carbon Emissions by CO2 per Geographical Region
#exclude 'World' as a region
geoarea=['Africa', 'Europe', 'Asia', 'Australia', 'South America', 'North America', "Antartica", 'Oceania', 'Caribbean', 'Central America']
region_df =recession_df[recession_df.geo_reg.isin(geoarea)]
print(region_df.shape)
# Out:
# (54, 29)

# %%
#find unique values
region_df['geo_reg'].unique()
# Out:
# array(['Africa', 'Asia', 'Australia', 'Caribbean', 'Central America',
#        'Europe', 'North America', 'Oceania', 'South America'],
#       dtype=object)

# %% [markdown]
# #### Carbon Emissions (by Region/Continent)

# %%
# great_recession_df.groupby('country').plot(x='year', y='co2', kind='line')
region_df.groupby(['geo_reg']).plot(x='year', y='co2_per_capita', kind='line')
# Out:
# geo_reg
# Africa             AxesSubplot(0.125,0.125;0.775x0.755)
# Asia               AxesSubplot(0.125,0.125;0.775x0.755)
# Australia          AxesSubplot(0.125,0.125;0.775x0.755)
# Caribbean          AxesSubplot(0.125,0.125;0.775x0.755)
# Central America    AxesSubplot(0.125,0.125;0.775x0.755)
# Europe             AxesSubplot(0.125,0.125;0.775x0.755)
# North America      AxesSubplot(0.125,0.125;0.775x0.755)
# Oceania            AxesSubplot(0.125,0.125;0.775x0.755)
# South America      AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
# plot line chart for region_df
region_df.plot(x='year', y='co2',kind= 'line', color="dodgerblue")
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# #### Africa

# %%
africa_df = region_df[region_df['geo_reg']=='Africa']
africa_df
# Out:
#     record_no  iso_code geo_reg  year  population  gdp       co2  \
# 6          27  notfound  Africa  2007   963022016  0.0  1120.938
# 7          28  notfound  Africa  2008   987624000  0.0  1173.883
# 8          29  notfound  Africa  2009  1013046016  0.0  1185.946
# 9          30  notfound  Africa  2010  1039304000  0.0  1206.780
# 10         31  notfound  Africa  2011  1066409984  0.0  1234.606
# 11         32  notfound  Africa  2012  1094343040  0.0  1240.355
#
#     co2_growth_prct  co2_growth_abs  consumption_co2  ...  coal_co2  \
# 6             3.891          41.981              0.0  ...   428.041
# 7             4.723          52.945              0.0  ...   452.250
# 8             1.028          12.063              0.0  ...   440.989
# 9             1.757          20.834              0.0  ...   439.305
# 10            2.306          27.825              0.0  ...   429.485
# 11            0.466           5.750              0.0  ...   426.070
#
# ...

# %%
# co2 per capita
africa = africa_df.plot.line(x="year",y= "co2_per_capita", color= 'red')
africa.set_xlabel("Africa")
africa.set_ylabel("CO2 Per Capita (tonnes)")
plt.title ("Africa CO2 Emissions Per Capita, 2007-2012")
plt.savefig("../../resources/images/africa_co2_per_capita.png", bbox_inches='tight')

# %%
# co2
africa_b = africa_df.plot.line(x="year",y= "co2", color= 'red')
africa_b.set_xlabel("Africa")
africa_b.set_ylabel("CO2 (million tonnes)")
plt.title ("Africa CO2 Emissions, 2007-2012")
plt.savefig("../../resources/images/africa_co2.png", bbox_inches='tight')

# %% [markdown]
# #### Asia

# %%
asia_df = region_df[region_df['geo_reg']=='Asia']
asia_df
# Out:
#     record_no  iso_code geo_reg  year  population  gdp        co2  \
# 66        227  notfound    Asia  2007 -2147483648  0.0  13919.476
# 67        228  notfound    Asia  2008 -2147483648  0.0  14708.063
# 68        229  notfound    Asia  2009 -2147483648  0.0  15276.685
# 69        230  notfound    Asia  2010 -2147483648  0.0  16327.225
# 70        231  notfound    Asia  2011 -2147483648  0.0  17520.494
# 71        232  notfound    Asia  2012 -2147483648  0.0  18238.782
#
#     co2_growth_prct  co2_growth_abs  consumption_co2  ...   coal_co2  \
# 66            5.548         731.623              0.0  ...   7641.944
# 67            5.665         788.587              0.0  ...   8213.032
# 68            3.866         568.622              0.0  ...   8576.564
# 69            6.877        1050.540              0.0  ...   9208.224
# 70            7.308        1193.269              0.0  ...  10101.106
# 71            4.100         718.288              0.0  ...  10449.331
#
# ...

# %%
# co2 per capita
asia = asia_df.plot.line(x="year",y= "co2_per_capita", color= 'green')
asia.set_xlabel("Asia")
asia.set_ylabel("CO2 Per Capita (tonnes)")
plt.title ("Asia CO2 Emissions Per Capita, 2007-2012")
plt.savefig("../../resources/images/asia.png", bbox_inches='tight')

# %%
# co2
asia_b = asia_df.plot.line(x="year",y= 'co2', color = 'green')
asia_b.set_xlabel("Asia")
asia_b.set_ylabel("CO2 (million tonnes)")
plt.title ("Asia CO2 Emissions, 2007-2012")
plt.savefig("../../resources/images/asia_co2.png", bbox_inches='tight')

# %% [markdown]
# #### Australia

# %%
aus_df = region_df[region_df['geo_reg']=='Australia']
aus_df
# Out:
#     record_no iso_code    geo_reg  year  population           gdp      co2  \
# 78        267      AUS  Australia  2007    20916000  8.770000e+11  399.842
# 79        268      AUS  Australia  2008    21332000  9.320000e+11  404.417
# 80        269      AUS  Australia  2009    21751000  9.270000e+11  407.463
# 81        270      AUS  Australia  2010    22155000  9.940000e+11  405.503
# 82        271      AUS  Australia  2011    22538000  1.030000e+12  404.173
# 83        272      AUS  Australia  2012    22904000  1.020000e+12  406.506
#
#     co2_growth_prct  co2_growth_abs  consumption_co2  ...  coal_co2  \
# 78            1.824           7.162          370.458  ...   203.432
# 79            1.144           4.575          364.061  ...   204.526
# 80            0.753           3.046          388.043  ...   206.050
# 81           -0.481          -1.961          383.216  ...   200.536
# 82           -0.328          -1.330          390.930  ...   192.125
# ...

# %%
# co2 per capita
aus = aus_df.plot.line(x="year",y= "co2_per_capita", color= 'purple')
aus.set_xlabel("Australia")
aus.set_ylabel("CO2 Per Capita (tonnes)")
plt.title ("Australia CO2 Emissions Per Capita, 2007-2012")
plt.savefig("../../resources/images/australia_co2_per_capita.png", bbox_inches='tight')

# %%
#co2
aus_b = aus_df.plot.line(x="year",y= "co2", color= 'purple')
aus_b.set_xlabel("Australia")
aus_b.set_ylabel("CO2 (million tonnes)")
plt.title ("Australia CO2 Emissions, 2007-2012")
plt.savefig("../../resources/images/australia_co2.png", bbox_inches='tight')

# %% [markdown]
# #### Antartica -- no info will be available/found

# %%
region_df[region_df['geo_reg']=='Antartica']
# Out:
# Empty DataFrame
# Columns: [record_no, iso_code, geo_reg, year, population, gdp, co2, co2_growth_prct, co2_growth_abs, consumption_co2, trade_co2, trade_co2_share, co2_per_capita, consumption_co2_per_capita, share_global_co2, cumulative_co2, co2_per_gdp, consumption_co2_per_gdp, cement_co2, coal_co2, flaring_co2, gas_co2, oil_co2, other_industry_co2, cement_co2_per_capita, coal_co2_per_capita, flaring_co2_per_capita, gas_co2_per_capita, oil_co2_per_capita]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# #### Caribbean

# %%
caribbean_df = region_df[region_df['geo_reg']=='Caribbean']
caribbean_df
# Out:
#      record_no  iso_code    geo_reg  year  population           gdp      co2  \
# 240       4550  notfound  Caribbean  2007    35635000  2.414263e+11  113.581
# 241       4551  notfound  Caribbean  2008    35924000  2.514810e+11  115.288
# 242       4552  notfound  Caribbean  2009    36221000  2.482405e+11  111.481
# 243       4553  notfound  Caribbean  2010    36521000  2.622229e+11  120.932
# 244       4554  notfound  Caribbean  2011    36837000  2.726787e+11  116.536
# 245       4555  notfound  Caribbean  2012    37163000  2.786986e+11  114.722
#
#      co2_growth_prct  co2_growth_abs  consumption_co2  ...  coal_co2  \
# 240          123.191           2.959           57.976  ...     2.103
# 241           35.471           1.702           59.447  ...     2.334
# 242           -8.603          -3.807           61.695  ...     2.291
# 243           92.698           9.453           62.583  ...     2.045
# 244          -96.388          -4.398           60.018  ...     2.742
# ...

# %%
# co2 per capita
car = caribbean_df.plot.line(x="year",y= "co2_per_capita", color= 'violet')
car.set_xlabel("Caribbean")
car.set_ylabel("CO2 Per Capita (tonnes)")
plt.title ("The Caribbean CO2 Emissions Per Capita, 2007-2012")
plt.savefig("../../resources/images/caribbean_co2_per_capita.png", bbox_inches='tight')

# %%
#co2
car_b = caribbean_df.plot.line(x="year",y= "co2", color= 'violet')
car_b.set_xlabel("Caribbean")
car_b.set_ylabel("CO2 (million tonnes)")
plt.title ("The Caribbean CO2 Emissions, 2007-2012")
plt.savefig("../../resources/images/caribbean_co2.png", bbox_inches='tight')

# %% [markdown]
# #### Central America

# %%
central_df = region_df[region_df['geo_reg']=='Central America']
central_df
# Out:
#      record_no  iso_code          geo_reg  year  population           gdp  \
# 252       4530  notfound  Central America  2007    41363000  2.607786e+11
# 253       4531  notfound  Central America  2008    42072000  2.702205e+11
# 254       4532  notfound  Central America  2009    42786000  2.763116e+11
# 255       4533  notfound  Central America  2010    43497000  2.910376e+11
# 256       4534  notfound  Central America  2011    44213000  3.125230e+11
# 257       4535  notfound  Central America  2012    44930000  3.230240e+11
#
#         co2  co2_growth_prct  co2_growth_abs  consumption_co2  ...  coal_co2  \
# 252  47.772           48.716           2.784           56.894  ...     2.107
# 253  45.922          -28.211          -1.851           60.430  ...     1.707
# 254  46.958           30.771           1.037           67.766  ...     1.472
# 255  46.949            4.912          -0.010           77.798  ...     1.847
# ...

# %%
# co2 per capita
cen = central_df.plot.line(x="year",y= "co2_per_capita", color= 'peru')
cen.set_xlabel("Central America")
cen.set_ylabel("CO2 Per Capita (tonnes)")
plt.title ("Central America CO2 Emissions Per Capita, 2007-2012")
plt.savefig("../../resources/images/cen_co2_per_capita.png", bbox_inches='tight')

# %%
#co2
cen_b = central_df.plot.line(x="year",y= "co2", color= 'peru')
cen_b.set_xlabel("Central America")
cen_b.set_ylabel("CO2 (million tonnes)")
plt.title ("Central America CO2 Emissions, 2007-2012")
plt.savefig("../../resources/images/cen_co2.png", bbox_inches='tight')

# %% [markdown]
# #### Europe

# %%
europe_df = region_df[region_df['geo_reg']=='Europe']
europe_df
# Out:
#      record_no  iso_code geo_reg  year  population  gdp       co2  \
# 426       1384  notfound  Europe  2007   731939008  0.0  6471.928
# 427       1385  notfound  Europe  2008   733416000  0.0  6399.412
# 428       1386  notfound  Europe  2009   734923008  0.0  5888.331
# 429       1387  notfound  Europe  2010   736412992  0.0  6115.876
# 430       1388  notfound  Europe  2011   737851008  0.0  6035.187
# 431       1389  notfound  Europe  2012   739225024  0.0  5981.732
#
#      co2_growth_prct  co2_growth_abs  consumption_co2  ...  coal_co2  \
# 426           -0.740         -48.239              0.0  ...  2035.777
# 427           -1.120         -72.516              0.0  ...  1961.769
# 428           -7.986        -511.081              0.0  ...  1748.247
# 429            3.864         227.544              0.0  ...  1816.719
# 430           -1.319         -80.689              0.0  ...  1861.339
# 431           -0.886         -53.455              0.0  ...  1903.252
#
# ...

# %%
# co2 per capita
eur = europe_df.plot.line(x="year",y= "co2_per_capita", color= 'blue')
eur.set_xlabel("Europe")
eur.set_ylabel("CO2 Per Capita (tonnes)")
plt.title ("Europe CCO2 Emissions Per Capita, 2007-2012")
plt.savefig("../../resources/images/europe_co2_per_capita.png", bbox_inches='tight')

# %%
#co2
eur_b = europe_df.plot.line(x="year",y= "co2", color= 'blue')
eur_b.set_xlabel("Europe")
eur_b.set_ylabel("CO2 (million tonnes)")
plt.title ("Europe CO2 Emissions, 2007-2012")
plt.savefig("../../resources/images/europe_co2.png", bbox_inches='tight')

# %% [markdown]
# #### North America

# %%
noram_df = region_df[region_df['geo_reg']=='North America']
noram_df
# Out:
#      record_no  iso_code        geo_reg  year  population  gdp       co2  \
# 905       2976  notfound  North America  2007   333668000  0.0  7364.799
# 906       2977  notfound  North America  2008   336952992  0.0  7161.331
# 907       2978  notfound  North America  2009   340182016  0.0  6668.865
# 908       2979  notfound  North America  2010   343287008  0.0  6886.207
# 909       2980  notfound  North America  2011   346251008  0.0  6782.770
# 910       2981  notfound  North America  2012   349092992  0.0  6598.315
#
#      co2_growth_prct  co2_growth_abs  consumption_co2  ...  coal_co2  \
# 905            1.511         109.657              0.0  ...  2373.802
# 906           -2.763        -203.468              0.0  ...  2328.494
# 907           -6.877        -492.466              0.0  ...  2040.092
# 908            3.259         217.342              0.0  ...  2161.748
# 909           -1.502        -103.437              0.0  ...  2049.559
# ...

# %%
# co2 per capita
noram = noram_df.plot.line(x="year",y= "co2_per_capita", color= 'orange')
noram.set_xlabel("North America")
noram.set_ylabel("CO2 Per Capita (tonnes)")
plt.title ("North America CO2 Emissions Per Capita, 2007-2012")
plt.savefig("../../resources/images/noram_co2_per_capita.png", bbox_inches='tight')

# %%
#co2
noram_b = noram_df.plot.line(x="year",y= "co2", color= 'orange')
noram_b.set_xlabel("North American")
noram_b.set_ylabel("CO2 (million tonnes)")
plt.title ("North America CO2 Emissions, 2007-2012")
plt.savefig("../../resources/images/noram_co2.png", bbox_inches='tight')

# %% [markdown]
# #### Oceania

# %%
oceania_df = region_df[region_df['geo_reg']=='Oceania']
oceania_df
# Out:
#      record_no  iso_code  geo_reg  year  population  gdp      co2  \
# 935       3076  notfound  Oceania  2007    34901000  0.0  448.584
# 936       3077  notfound  Oceania  2008    35561000  0.0  452.537
# 937       3078  notfound  Oceania  2009    36225000  0.0  453.068
# 938       3079  notfound  Oceania  2010    36873000  0.0  451.950
# 939       3080  notfound  Oceania  2011    37498000  0.0  450.336
# 940       3081  notfound  Oceania  2012    38105000  0.0  454.209
#
#      co2_growth_prct  co2_growth_abs  consumption_co2  ...  coal_co2  \
# 935            1.884           8.297              0.0  ...   210.784
# 936            0.881           3.953              0.0  ...   213.451
# 937            0.117           0.531              0.0  ...   213.091
# 938           -0.247          -1.118              0.0  ...   207.202
# 939           -0.357          -1.613              0.0  ...   198.820
# 940            0.860           3.873              0.0  ...   197.244
#
# ...

# %%
# co2 per capita
oce = oceania_df.plot.line(x="year",y= "co2_per_capita", color= 'turquoise')
oce.set_xlabel("Oceania")
oce.set_ylabel("CO2 Per Capita (tonnes)")
plt.title ("Oceania CO2 Emissions Per Capita, 2007-2012")
plt.savefig("../../resources/images/oceania_co2_per_capita.png", bbox_inches='tight')

# %%
#co2
oce_b = oceania_df.plot.line(x="year",y= "co2", color= 'turquoise')
oce_b.set_xlabel("Oceania")
oce_b.set_ylabel("CO2 (million tonnes)")
plt.title ("Oceania CO2 Emissions, 2007-2012")
plt.savefig("../../resources/images/oceania_co2.png", bbox_inches='tight')

# %% [markdown]
# #### South America

# %%
soam_df = region_df[region_df['geo_reg']=='South America']
soam_df
# Out:
#       record_no  iso_code        geo_reg  year  population  gdp       co2  \
# 1145       3773  notfound  South America  2007           0  0.0   905.885
# 1146       3774  notfound  South America  2008           0  0.0   974.014
# 1147       3775  notfound  South America  2009           0  0.0   960.679
# 1148       3776  notfound  South America  2010           0  0.0  1051.882
# 1149       3777  notfound  South America  2011           0  0.0  1064.184
# 1150       3778  notfound  South America  2012           0  0.0  1130.009
#
#       co2_growth_prct  co2_growth_abs  consumption_co2  ...  coal_co2  \
# 1145            1.954          17.362              0.0  ...    84.041
# 1146            7.521          68.129              0.0  ...    91.245
# 1147           -1.369         -13.335              0.0  ...    76.844
# 1148            9.494          91.203              0.0  ...    96.544
# 1149            1.170          12.302              0.0  ...   107.382
# ...

# %%
# co2 per capita
soam = soam_df.plot.line(x="year",y= "co2_per_capita", color= 'teal')
soam.set_xlabel("South America")
soam.set_ylabel("CO2 Per Capita (tonnes)")
plt.title ("South America CO2 Emissions Per Capita, 2007-2012")
plt.savefig("../../resources/images/soam_co2_per_capita.png", bbox_inches='tight')

# %%
#co2
soam_b = soam_df.plot.line(x="year",y= "co2", color= 'teal')
soam_b.set_xlabel("South America")
soam_b.set_ylabel("CO2 (million tonnes)")
plt.title ("South America CO2 Emissions, 2007-2012")
plt.savefig("../../resources/images/soam_co2.png", bbox_inches='tight')

# %%
# plot the average of CO2 emissions by Geographical region
#average Co2 by region
average_region=region_df.groupby(["geo_reg"]).mean()['co2']
average_region
# Out:
# geo_reg
# Africa              1193.751333
# Asia               15998.454167
# Australia            404.650667
# Caribbean            115.423333
# Central America       47.606167
# Europe              6148.744333
# North America       6910.381167
# Oceania              451.780667
# South America       1014.442167
# Name: co2, dtype: float64

# %%
#bar
colors=['red','green','purple','violet','peru','blue','orange','turquoise','teal']
# region_df.groupby(by="geo_reg").mean()['co2'].plot(kind="bar", color=colors)
average_region.plot(kind="bar", color=colors)
plt.ylabel("CO2(million tonnes)")
plt.xlabel("Geographical Region")
plt.title("Average of CO2 Emisions by Geographical Region, 2007-2012")
plt.xticks(rotation=45)

#note
plt.text(10, 10, "Note: Exclusive of Geographical Region: Antartica.", fontsize="12")

plt.savefig("../../resources/images/avg_geo_reg_co2_bar.png", bbox_inches='tight')
plt.figure(figsize=(15,5))

# %%
# plot the average of CO2 emissions by Geographical region
#average Co2_per_ capita by region
co2_capita=region_df.groupby(["geo_reg"]).mean()['co2_per_capita']
co2_capita
# Out:
# geo_reg
# Africa               1.189167
# Asia                 3.817333
# Australia           18.465333
# Caribbean          155.308000
# Central America      9.267000
# Europe               8.350667
# North America       12.859167
# Oceania             12.505500
# South America        2.596833
# Name: co2_per_capita, dtype: float64

# %%
#bar
colors=['red','green','purple','violet','peru','blue','orange','turquoise','teal']
# region_df.groupby(by="geo_reg").mean()['co2'].plot(kind="bar", color=colors)
co2_capita.plot(kind="bar", color=colors)
plt.ylabel("CO2(million tonnes)")
plt.xlabel("Geographical Region")
plt.title("Average of CO2 Emisions Per Capita by Geographical Region, 2007-2012")
plt.xticks(rotation=45)

#note
# plt.text(10, 10, "Note: Exclusive of Geographical Region: Antartica.", fontsize="12")

plt.savefig("../../resources/images/avg_geo_reg_co2_capita_bar_without_note.png", bbox_inches='tight')
plt.figure(figsize=(15,5))

# %%
#pie
labels = 'Africa', 'Asia', 'Australia', 'Caribbean', 'Central America', 'Europe', 'North America', 'Oceania','South America'

sizes= [3.7,49.6, 1.3, 0.4,0.1,19,21.4,1.4,3.1] 
labels = [f'{l}, {s:0.1f}%' for l, s in zip(labels, sizes)]
plt.pie(average_region, 
            colors=colors,
        explode=[0.0, 0.2, 0.1, 0.3, 0.5, 0.0, 0.0, 0.0, 0.0],
#         autopct='%1.1f%%', #only to add percentage to pie chart
        shadow=True, startangle=45,)
plt.legend( labels, loc='best', bbox_to_anchor=(-0.1, 1.),
           fontsize=10) 
plt.title("Average of CO2 Emisions by Georgraphical Region, 2007-2012")
#note
# plt.text(10, 10, "Note: Exclusive of Geographical Region: Antartica.", fontsize="12")

#save
plt.savefig("../../resources/images/avg_geo_reg_co2_pie.png", bbox_inches='tight')
plt.tight_layout()
plt.autoscale()

# %%
#plot regions per capita
# "test"  plot multiple regions 
axreg = plt.gca()
axreg.set_ylabel("CO2 Per Capita (tonnes)")

# #creating subplots
# fig, axreg = plt.subplots(2)
# axreg[0].plot(ax6_b,ax7 )
# axreg[1].plot(ax5,ax4 )


africa_df.plot.line(x="year",y= "co2_per_capita", color= 'red', label='Africa', ax=axreg)
asia_df.plot.line(x="year",y="co2_per_capita" ,color= 'green', label='Asia', ax=axreg)
aus_df.plot.line(x="year",y="co2_per_capita", color= 'purple', label='Australia', ax=axreg)
# caribbean_df.plot.line(x="year",y="co2_per_capita", color= 'violet',label='Caribbean', ax=axreg)
central_df.plot.line(x="year",y="co2_per_capita", color= 'peru',label='Central America', ax=axreg)
europe_df.plot.line(x="year",y="co2_per_capita", color= 'blue',label='Europe', ax=axreg)
noram_df.plot.line(x="year",y="co2_per_capita", color= 'orange',label='North America', ax=axreg)
oceania_df.plot.line(x="year",y="co2_per_capita", color= 'turquoise', label='Oceania', ax=axreg)
soam_df.plot.line(x="year",y="co2_per_capita", color= 'teal', label='South America', ax=axreg)
caribbean_df.plot.line(x="year",y="co2_per_capita", color= 'violet',label='Caribbean', ax=axreg)


# plt.figure(figsize=(15,5))
plt.title("CO2 Emissions Per Capita, By Geographical Region 2007-2012")
plt.savefig("../../resources/images/all_reg_co2_per_capita_multiline.png", bbox_inches='tight')

plt.show()

# %%
#without The Carribean 
axreg = plt.gca()
axreg.set_ylabel("CO2 Per Capita (tonnes)")

# #creating subplots
# fig, axreg = plt.subplots(2)
# axreg[0].plot(ax6_b,ax7 )
# axreg[1].plot(ax5,ax4 )


africa_df.plot.line(x="year",y= "co2_per_capita", color= 'red', label='Africa', ax=axreg)
asia_df.plot.line(x="year",y="co2_per_capita" ,color= 'green', label='Asia', ax=axreg)
aus_df.plot.line(x="year",y="co2_per_capita", color= 'purple', label='Australia', ax=axreg)
# caribbean_df.plot.line(x="year",y="co2_per_capita", color= 'violet',label='Caribbean', ax=axreg)
central_df.plot.line(x="year",y="co2_per_capita", color= 'peru',label='Central America', ax=axreg)
europe_df.plot.line(x="year",y="co2_per_capita", color= 'blue',label='Europe', ax=axreg)
noram_df.plot.line(x="year",y="co2_per_capita", color= 'orange',label='North America', ax=axreg)
oceania_df.plot.line(x="year",y="co2_per_capita", color= 'turquoise', label='Oceania', ax=axreg)
soam_df.plot.line(x="year",y="co2_per_capita", color= 'teal', label='South America', ax=axreg)
# caribbean_df.plot.line(x="year",y="co2_per_capita", color= 'violet',label='Caribbean', ax=axreg)


# plt.figure(figsize=(15,5))
plt.title("CO2 Emissions Per Capita, By Geographical Region,  2007-2012")
plt.savefig("../../resources/images/all_reg_co2_per_capita_multiline_without_car.png", bbox_inches='tight')



#note
# plt.text(10, 10, "Note: Exclusive of Geographical Region: Antartica and The Caribbeans.", fontsize="12")

plt.show()
